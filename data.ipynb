# %%
import os
import pandas as pd
import numpy as np
import datetime
import tqdm
from tqdm import trange
import json

# %%
with open('China.json',encoding='utf-8') as tf:
    data=json.load(tf)

# %%
data

# %%
dict={}
for i in range(len(data['features'])):
    dict[data['features'][i]['properties']['name']]=i

# %%
print(dict)
# Out:
# {'新疆': 0, '西藏': 1, '内蒙古': 2, '青海': 3, '四川': 4, '黑龙江': 5, '甘肃': 6, '云南': 7, '广西': 8, '湖南': 9, '陕西': 10, '广东': 11, '吉林': 12, '河北': 13, '湖北': 14, '贵州': 15, '山东': 16, '江西': 17, '河南': 18, '辽宁': 19, '山西': 20, '安徽': 21, '福建': 22, '浙江': 23, '江苏': 24, '重庆': 25, '宁夏': 26, '海南': 27, '台湾': 28, '北京': 29, '天津': 30, '上海': 31, '香港': 32, '澳门': 33}

# %%
df= pd.read_csv('1.csv',encoding='gbk')

# %%
df.iloc[754:]
# Out:
#       Year  Provenceid  Provence          tGDP    first_num    second_num  \
# 754   1978         142        中国   3678.699951  1018.500000   1755.199951
# 755   1978      510000       四川省    184.610001    82.199997     65.550003
# 756   1978      650000  新疆维吾尔自治区     39.070000    13.970000     18.350000
# 757   1978      530000       云南省     69.050003    29.459999     27.580000
# 758   1978      620000       甘肃省     64.730003    13.210000     39.040001
# ...    ...         ...       ...           ...          ...           ...
# 2084  2019      460000       海南省   5308.930176  1080.359985   1099.030029
# 2085  2019      430000       湖南省  39752.121090  3646.949951  14946.980470
# 2086  2019      650000  新疆维吾尔自治区  13597.110350  1781.750000   4795.500000
# 2087  2019      540000     西藏自治区   1697.819946   138.190002    635.619995
# 2088  2019      420000       湖北省  45828.308590  3809.090088  19098.619140
#
#          third_num  first_por  second_por  third_por    avgpeople
# 754     905.099976  27.700001   47.700001  24.600000    385.00000
# 755      36.860001  44.526299   35.507301  19.966400    261.00000
# 756       6.750000  35.756302   46.966999  17.276699    313.00000
# 757      12.010000  42.664700   39.942101  17.393200    226.00000
# 758      12.480000  20.407801   60.312099  19.280100    348.00000
# ...            ...        ...         ...        ...          ...
# 2084   3129.540039  20.299999   20.700001  59.000000  56506.82813
# 2085  21158.189450   9.200000   37.599998  53.200001  57540.26172
# 2086   7019.859863  13.100000   35.299999  51.599998  54280.00000
# 2087    924.010010   8.200000   37.400002  54.400002  48902.00000
# 2088  22920.599610   8.300000   41.700001  50.000000  77386.53906
#
# [1335 rows x 11 columns]

# %%
# Out:
# 1952

# %%
res=0
previ=-1
prevyear=1952
for i in range(len(df)):
    year=df['Year'][i]
    if(year!=prevyear):
        if(i-previ==32):
            res=i
        prevyear=year
        previ=i-1
res
# Out:
# 1033

# %%
df[res:]
# Out:
#       Year  Provenceid  Provence          tGDP    first_num    second_num  \
# 1033  1987         142        中国  12174.599610  3204.500000   5274.000000
# 1034  1987      650000  新疆维吾尔自治区    148.509995    56.180000     50.299999
# 1035  1987      370000       山东省    892.289978   287.309998    384.570007
# 1036  1987      630000       青海省     43.380001    11.740000     16.610001
# 1037  1987      500000       重庆市    190.350006    62.689999     78.349998
# ...    ...         ...       ...           ...          ...           ...
# 2084  2019      460000       海南省   5308.930176  1080.359985   1099.030029
# 2085  2019      430000       湖南省  39752.121090  3646.949951  14946.980470
# 2086  2019      650000  新疆维吾尔自治区  13597.110350  1781.750000   4795.500000
# 2087  2019      540000     西藏自治区   1697.819946   138.190002    635.619995
# 2088  2019      420000       湖北省  45828.308590  3809.090088  19098.619140
#
#          third_num  first_por  second_por  third_por    avgpeople
# 1033   3696.199951  26.299999   43.299999  30.400000   1123.00000
# 1034     42.029999  37.829102   33.869801  28.301100   1053.00000
# 1035    220.410004  32.199200   43.099201  24.701599   1131.00000
# 1036     15.030000  27.063200   38.289501  34.647301   1018.00000
# 1037     49.310001  32.934101   41.160999  25.904900    673.00000
# ...            ...        ...         ...        ...          ...
# 2084   3129.540039  20.299999   20.700001  59.000000  56506.82813
# 2085  21158.189450   9.200000   37.599998  53.200001  57540.26172
# 2086   7019.859863  13.100000   35.299999  51.599998  54280.00000
# 2087    924.010010   8.200000   37.400002  54.400002  48902.00000
# 2088  22920.599610   8.300000   41.700001  50.000000  77386.53906
#
# [1056 rows x 11 columns]

# %%
df.iloc[res:].to_csv('t1.csv',index=False)

# %%
df= pd.read_csv('t1.csv')

# %%
df
# Out:
#       Year  Provenceid  Provence          tGDP    first_num    second_num  \
# 0     1987         142        中国  12174.599610  3204.500000   5274.000000
# 1     1987      650000  新疆维吾尔自治区    148.509995    56.180000     50.299999
# 2     1987      370000       山东省    892.289978   287.309998    384.570007
# 3     1987      630000       青海省     43.380001    11.740000     16.610001
# 4     1987      500000       重庆市    190.350006    62.689999     78.349998
# ...    ...         ...       ...           ...          ...           ...
# 1051  2019      460000       海南省   5308.930176  1080.359985   1099.030029
# 1052  2019      430000       湖南省  39752.121090  3646.949951  14946.980470
# 1053  2019      650000  新疆维吾尔自治区  13597.110350  1781.750000   4795.500000
# 1054  2019      540000     西藏自治区   1697.819946   138.190002    635.619995
# 1055  2019      420000       湖北省  45828.308590  3809.090088  19098.619140
#
#          third_num  first_por  second_por  third_por    avgpeople
# 0      3696.199951  26.299999   43.299999  30.400000   1123.00000
# 1        42.029999  37.829102   33.869801  28.301100   1053.00000
# 2       220.410004  32.199200   43.099201  24.701599   1131.00000
# 3        15.030000  27.063200   38.289501  34.647301   1018.00000
# 4        49.310001  32.934101   41.160999  25.904900    673.00000
# ...            ...        ...         ...        ...          ...
# 1051   3129.540039  20.299999   20.700001  59.000000  56506.82813
# 1052  21158.189450   9.200000   37.599998  53.200001  57540.26172
# 1053   7019.859863  13.100000   35.299999  51.599998  54280.00000
# 1054    924.010010   8.200000   37.400002  54.400002  48902.00000
# 1055  22920.599610   8.300000   41.700001  50.000000  77386.53906
#
# [1056 rows x 11 columns]
